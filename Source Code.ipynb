# %%
# Install a pip pandas package in the current Jupyter kernel
import sys

#Basic Packages related to Data Analysis
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install scipy

#Packages required for Oracle Table Insert
# !{sys.executable} -m pip install sqlalchemy
# !{sys.executable} -m pip install cx_oracle
# !{sys.executable} -m pip install oracledb --no-deps

#Package for Yahoo Finance API Stock Information
# !{sys.executable} -m pip install yfinance --upgrade --no-cache-dir

#Package for Ticker Symbol Related information
# !{sys.executable} -m pip install pytickersymbols

#Package to cache requests to prevent server overload
# !{sys.executable} -m pip install requests-cache
# Out:
# Requirement already satisfied: pandas in ./.venv/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in ./.venv/lib/python3.12/site-packages (from pandas) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: numpy in ./.venv/lib/python3.12/site-packages (2.0.0)
# Requirement already satisfied: scipy in ./.venv/lib/python3.12/site-packages (1.14.0)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in ./.venv/lib/python3.12/site-packages (from scipy) (2.0.0)
# Requirement already satisfied: sqlalchemy in ./.venv/lib/python3.12/site-packages (2.0.31)
# Requirement already satisfied: typing-extensions>=4.6.0 in ./.venv/lib/python3.12/site-packages (from sqlalchemy) (4.12.2)
# Requirement already satisfied: cx_oracle in ./.venv/lib/python3.12/site-packages (8.3.0)
# Requirement already satisfied: oracledb in ./.venv/lib/python3.12/site-packages (2.2.1)
# Requirement already satisfied: yfinance in ./.venv/lib/python3.12/site-packages (0.2.40)
# Requirement already satisfied: pandas>=1.3.0 in ./.venv/lib/python3.12/site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in ./.venv/lib/python3.12/site-packages (from yfinance) (2.0.0)
# Requirement already satisfied: requests>=2.31 in ./.venv/lib/python3.12/site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in ./.venv/lib/python3.12/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in ./.venv/lib/python3.12/site-packages (from yfinance) (5.2.2)
# Requirement already satisfied: platformdirs>=2.0.0 in ./.venv/lib/python3.12/site-packages (from yfinance) (4.2.2)
# Requirement already satisfied: pytz>=2022.5 in ./.venv/lib/python3.12/site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in ./.venv/lib/python3.12/site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in ./.venv/lib/python3.12/site-packages (from yfinance) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in ./.venv/lib/python3.12/site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in ./.venv/lib/python3.12/site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in ./.venv/lib/python3.12/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in ./.venv/lib/python3.12/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests>=2.31->yfinance) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests>=2.31->yfinance) (2024.7.4)
# Requirement already satisfied: pytickersymbols in ./.venv/lib/python3.12/site-packages (1.15.0)
# Requirement already satisfied: requests-cache in ./.venv/lib/python3.12/site-packages (1.2.1)
# Requirement already satisfied: attrs>=21.2 in ./.venv/lib/python3.12/site-packages (from requests-cache) (23.2.0)
# Requirement already satisfied: cattrs>=22.2 in ./.venv/lib/python3.12/site-packages (from requests-cache) (23.2.3)
# Requirement already satisfied: platformdirs>=2.5 in ./.venv/lib/python3.12/site-packages (from requests-cache) (4.2.2)
# Requirement already satisfied: requests>=2.22 in ./.venv/lib/python3.12/site-packages (from requests-cache) (2.32.3)
# Requirement already satisfied: url-normalize>=1.4 in ./.venv/lib/python3.12/site-packages (from requests-cache) (1.4.3)
# Requirement already satisfied: urllib3>=1.25.5 in ./.venv/lib/python3.12/site-packages (from requests-cache) (1.26.19)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests>=2.22->requests-cache) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests>=2.22->requests-cache) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests>=2.22->requests-cache) (2024.7.4)
# Requirement already satisfied: six in ./.venv/lib/python3.12/site-packages (from url-normalize>=1.4->requests-cache) (1.16.0)

# %%
#Extarct Ticker Symbols
import pandas as pd
from pytickersymbols import PyTickerSymbols

try:
    # Fetch DAX stocks using PyTickerSymbols
    stock_data = PyTickerSymbols()
    german_stocks = stock_data.get_stocks_by_index('DAX')

    # Convert german_stocks to a DataFrame
    ticker_symbols = pd.DataFrame(german_stocks)['symbol']

    ticker_symbols = ticker_symbols[ticker_symbols.isin(['LIN', 'MRK', 'AIR', 'BNR', 'MTX', 'ENR', 'DTG', 'MBG'])]

    # Display the DAX ticker symbols DataFrame
    print("DAX Ticker Symbols:")
    print(ticker_symbols)

except Exception as e:
    print(f"Error fetching ticker symbols: {str(e)}")
# Out:
# DAX Ticker Symbols:
# 18    LIN
# 19    MRK
# 26    AIR
# 27    BNR
# 29    MTX
# 36    ENR
# 38    DTG
# 39    MBG
# Name: symbol, dtype: object

# %%
import yfinance as yf
import requests_cache
from datetime import datetime

# Function to fetch Ticker information
def fetch_data_for_symbol(symbol, session):
    ticker = yf.Ticker(symbol, session=session)
    symbol_info = ticker.info
    return symbol_info

# Function to fetch historical data for a Ticker
def fetch_historical_data(symbol, session):
    start_date = '2021-01-01'
    end_date = datetime.today().strftime('%Y-%m-%d')  # Current date
    data = yf.download(symbol, start=start_date, end=end_date, session=session)
    data.reset_index(inplace=True)  # Reset the index to make the date a column
    data['Symbol'] = symbol  # Add symbol column
    return data

#Cache Requests to avoid flooding of requests
requests_cache.install_cache('yfinance_cache', backend='sqlite', expire_after=3600)
session = requests_cache.CachedSession('yfinance.cache')
session.headers['User-agent'] = 'my-program/1.0'

#Initialize list
symbol_info_list = []
historical_data_dfs = []

for symbol in ticker_symbols:
    # Call Function to collect Ticker information & Append it
    symbol_info = fetch_data_for_symbol(symbol, session)
    symbol_info_list.append(symbol_info)
    
    # Call Function to fetch historical data and merge with Ticker information
    historical_data = fetch_historical_data(symbol, session)
    historical_data_dfs.append(historical_data)

df = pd.DataFrame(symbol_info_list)
hist_data = pd.concat(historical_data_dfs)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
#Validation of Ticker Information
df.head(10)
# Out:
#                          address1         city         zip         country  \
# 0    Forge, 43 Church Street West       Woking    GU21 6HT  United Kingdom
# 1         126 East Lincoln Avenue       Rahway       07065   United States
# 2                   One AAR Place    Wood Dale       60191   United States
# 3  No. 5, Xingdao Ring Road North    Guangzhou      510005           China
# 4                622 Third Avenue     New York  10017-6707   United States
# 5  533 Maryville University Drive  Saint Louis       63141   United States
# 6                             NaN          NaN         NaN             NaN
# 7                             NaN          NaN         NaN             NaN
#
#              phone                            website  \
# 0  44 14 8324 2200              https://www.linde.com
# 1     908 740 4000              https://www.merck.com
# 2     630 227 2000            https://www.aarcorp.com
# 3  86 20 3403 7871          https://www.brbiotech.com
# 4     212 878 1800       https://www.mineralstech.com
# 5     314 985 2000  https://www.energizerholdings.com
# 6              NaN                                NaN
# 7              NaN                                NaN
#
#                        industry                 industryKey  \
# 0           Specialty Chemicals         specialty-chemicals
# 1  Drug Manufacturers - General  drug-manufacturers-general
# 2           Aerospace & Defense           aerospace-defense
# 3        Diagnostics & Research        diagnostics-research
# 4           Specialty Chemicals         specialty-chemicals
# 5  Electrical Equipment & Parts  electrical-equipment-parts
# 6                           NaN                         NaN
# 7                           NaN                         NaN
#
#                    industryDisp           sector  ... revenueGrowth  \
# 0           Specialty Chemicals  Basic Materials  ...        -0.011
# 1  Drug Manufacturers - General       Healthcare  ...         0.089
# 2           Aerospace & Defense      Industrials  ...         0.089
# 3        Diagnostics & Research       Healthcare  ...        -0.119
# 4           Specialty Chemicals  Basic Materials  ...        -0.021
# 5  Electrical Equipment & Parts      Industrials  ...        -0.030
# 6                           NaN              NaN  ...           NaN
# 7                           NaN              NaN  ...           NaN
#
#   grossMargins ebitdaMargins  operatingMargins financialCurrency  \
# 0      0.47264       0.37246           0.25951               USD
# 1      0.74851       0.34544           0.42466               USD
# 2      0.19096       0.08688           0.05852               USD
# 3      0.67266      -0.90783          -1.00163               CNY
# 4      0.24200       0.18019           0.14462               USD
# 5      0.39711       0.19229           0.16599               USD
# 6          NaN           NaN               NaN               NaN
# 7          NaN           NaN               NaN               NaN
#
#    trailingPegRatio  state                                          irWebsite  \
# 0            2.6512    NaN                                                NaN
# 1            0.0984     NJ           http://www.merck.com/investors/home.html
# 2               NaN     IL  http://phx.corporate-ir.net/phoenix.zhtml?c=11...
# 3               NaN    NaN                                                NaN
# 4               NaN     NY  http://investors.mineralstech.com/phoenix.zhtm...
# 5               NaN     MO                                                NaN
# 6               NaN    NaN                                                NaN
# 7               NaN    NaN                                                NaN
#
#                     address2           fax
# 0                        NaN           NaN
# 1                        NaN           NaN
# 2  1100 North Wood Dale Road  630 227 2039
# 3   International Bio Island           NaN
# 4                 38th Floor           NaN
# 5                        NaN           NaN
# 6                        NaN           NaN
# 7                        NaN           NaN
#
# [8 rows x 134 columns]

# %%
#Validation of Historical Information
hist_data.head(10)
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2021-01-04  266.709991  267.290009  257.369995  258.809998  246.256989
# 1 2021-01-05  257.559998  263.239990  257.559998  262.869995  250.120056
# 2 2021-01-06  261.399994  274.579987  261.390015  271.500000  258.331482
# 3 2021-01-07  269.059998  273.760010  269.000000  270.720001  257.589355
# 4 2021-01-08  272.029999  272.380005  267.929993  270.399994  257.284882
# 5 2021-01-11  264.239990  269.089996  264.190002  267.529999  254.554077
# 6 2021-01-12  265.010010  267.589996  263.670013  266.619995  253.688217
# 7 2021-01-13  266.649994  268.529999  266.209991  267.730011  254.744308
# 8 2021-01-14  267.179993  267.279999  263.540009  263.690002  250.900360
# 9 2021-01-15  261.910004  261.910004  256.899994  258.089996  245.571960
#
#     Volume Symbol
# 0  1741300    LIN
# 1  1620000    LIN
# 2  2586600    LIN
# 3  1757800    LIN
# 4  1879300    LIN
# 5  1913200    LIN
# 6  1785200    LIN
# 7  1518800    LIN
# 8  1903400    LIN
# 9  1955300    LIN

# %%
import json

#Rename Column to avoid errors during inserts
df.rename(columns={'52WeekChange': 'WeekChange_52'}, inplace=True)

#Convert Column Name to UpperCase for Table Insert
df.columns = df.columns.str.upper()

#For CLOB data, json the string for insert
df['COMPANYOFFICERS'] = df['COMPANYOFFICERS'].apply(json.dumps)

# %%
import cx_Oracle

#Initialize Oracle Client to setup Thick Connectivity
cx_Oracle.init_oracle_client(lib_dir="/Users/perinban/Downloads/instantclient_23_3")

# %%
from sqlalchemy import create_engine,text

#Create Engine to load data to data lake table
engine = create_engine('oracle://"dss_stock":stock@localhost:1521/?service_name=ORCL')

with engine.connect() as connection:
    connection.execute(text("TRUNCATE TABLE ticker_info"))
    connection.commit()

#Load data to the Data Lake Table
try:
    df.to_sql('ticker_info', con=engine, if_exists='append', index=False)
    print("Data insertion successful.")
except Exception as e:
    print(f"Error inserting data: {str(e)}")
# Out:
# Data insertion successful.

# %%
#Rename Column to avoid errors during inserts
hist_data.rename(columns={'Adj Close': 'AdjClose', 'Date': 'StockDate'}, inplace=True)

#Convert Column Name to UpperCase for Table Insert
hist_data.columns = hist_data.columns.str.upper()

# %%
#Initialize variables
hist_data_reject = []

#Trim Additional Spaces in All Object columns
hist_data = hist_data.apply(lambda x: x.str.strip() if isinstance(x, str) else x,axis=1)

# %%
#Duplicate Condition Check

#Remove Duplicate data on the sorted data
dup_df = hist_data.duplicated(subset=['STOCKDATE','SYMBOL'], keep='first')

#Drop the Duplicate records from source and store in separate dataframe
rejected_rows = hist_data[dup_df].copy()
rejected_rows['REJECT_REASON'] = f"Duplicate Data found"
hist_data_reject.append(rejected_rows)

hist_data.drop(rejected_rows.index, inplace=True)
hist_data.reset_index(drop=True)
# Out:
#       STOCKDATE        OPEN        HIGH         LOW       CLOSE    ADJCLOSE  \
# 0    2021-01-04  266.709991  267.290009  257.369995  258.809998  246.256989
# 1    2021-01-05  257.559998  263.239990  257.559998  262.869995  250.120056
# 2    2021-01-06  261.399994  274.579987  261.390015  271.500000  258.331482
# 3    2021-01-07  269.059998  273.760010  269.000000  270.720001  257.589355
# 4    2021-01-08  272.029999  272.380005  267.929993  270.399994  257.284882
# ...         ...         ...         ...         ...         ...         ...
# 6829 2024-07-02   21.400000   21.430000   21.370001   21.389999   21.389999
# 6830 2024-07-03   21.450001   21.549999   21.440001   21.510000   21.510000
# 6831 2024-07-05   21.610001   21.670000   21.590000   21.660000   21.660000
# 6832 2024-07-08   21.650000   21.690001   21.620001   21.670000   21.670000
# 6833 2024-07-09   21.650000   21.709999   21.620001   21.700001   21.700001
#
#        VOLUME SYMBOL
# 0     1741300    LIN
# 1     1620000    LIN
# 2     2586600    LIN
# 3     1757800    LIN
# 4     1879300    LIN
# ...       ...    ...
# 6829  1449900    MBG
# 6830   399100    MBG
# 6831   369700    MBG
# 6832   859100    MBG
# 6833   852200    MBG
#
# [6834 rows x 8 columns]

# %%
#Null Condition Check in required non_decimal columns
for col in ['STOCKDATE', 'SYMBOL' ]:

    null_chk = hist_data[col].isna() | (hist_data[col] == '')
    
    #Drop the record if null found in mandate columns
    if null_chk.any():
        rejected_rows = hist_data[null_chk].copy()
        rejected_rows['REJECT_REASON'] = f"Null/Blank found for {col}"
        hist_data_reject.append(rejected_rows)
        hist_data.drop(rejected_rows.index, inplace=True)
        hist_data.reset_index(drop=True) 

print(hist_data_reject)
# Out:
# [Empty DataFrame
# Columns: [STOCKDATE, OPEN, HIGH, LOW, CLOSE, ADJCLOSE, VOLUME, SYMBOL, REJECT_REASON]
# Index: []]

# %%
#Fill Missing Values with Mean if any null value identified for the required column

columns = ['OPEN', 'HIGH', 'LOW', 'CLOSE', 'ADJCLOSE', 'VOLUME']
for col in columns:
    hist_data[col] = hist_data[col].fillna(hist_data[col].mean())

# %%
#Validation of records if there is any issue with data
hist_data.isnull().sum().sort_values(ascending=True)
# Out:
# STOCKDATE    0
# OPEN         0
# HIGH         0
# LOW          0
# CLOSE        0
# ADJCLOSE     0
# VOLUME       0
# SYMBOL       0
# dtype: int64

# %%
from scipy.stats import zscore

# Fix Bias - Removing Outliers - Z-Score Method

def remove_outliers_zscore(hist_data, attribute):
    # Compute Z-scores
    hist_data['zscore'] = zscore(hist_data[attribute])
    # Define the threshold
    threshold = 3
    # Identify outliers
    outliers = hist_data[(hist_data['zscore'] < -threshold) | (hist_data['zscore'] > threshold)]
    # Prepare the rejected data with reasons
    rejects = outliers.copy()
    rejects['REJECT_REASON'] = f"Removed as part of outliers in {attribute}"
    rejects.drop(columns=['zscore'], inplace=True)
    hist_data_reject.append(rejects)
    # Remove outliers
    hist_data = hist_data.loc[(hist_data['zscore'] >= -threshold) & (hist_data['zscore'] <= threshold)].copy()
    # Drop the Z-score column
    hist_data.drop(columns=['zscore'], inplace=True)
    hist_data.reset_index(drop=True) 
    
    return hist_data

for attribute in ['OPEN','HIGH','LOW','CLOSE','ADJCLOSE','VOLUME']:
    hist_data = remove_outliers_zscore(hist_data, attribute)

# %%
# Concatenate all rejected DataFrames into a single DataFrame
if hist_data_reject:
    hist_data_rejects = pd.concat(hist_data_reject).reset_index(drop=True)
    
    # Group by the 'REJECT_REASON' column and get the count of records for each reason
    print(hist_data_rejects.groupby('REJECT_REASON').size().reset_index(name='count'))
else:
    hist_data_rejects = pd.DataFrame()
# Out:
#                              REJECT_REASON  count
# 0  Removed as part of outliers in ADJCLOSE    144
# 1     Removed as part of outliers in CLOSE     88
# 2      Removed as part of outliers in HIGH     75
# 3       Removed as part of outliers in LOW    112
# 4      Removed as part of outliers in OPEN    105
# 5    Removed as part of outliers in VOLUME    104

# %%
#Delete Existing data from Data Reject Table
with engine.connect()  as connection:
    connection.execute(text("TRUNCATE TABLE stock_history_reject"))
    connection.commit()

#Load data to the Data Lake Table
hist_data_rejects.to_sql('stock_history_reject', con=engine, if_exists='append', index=False)
# Out:
# 628

# %%
#Add Additional Calculated fields required for visualisation

import numpy as np

# Extract year & Month from the 'Stock Date' column
hist_data['YEAR'] = hist_data['STOCKDATE'].dt.year
hist_data['MONTH'] = hist_data['STOCKDATE'].dt.month

#Group by Symbol and Year with Adj Close
adj_close_by_symbol = hist_data.groupby(['SYMBOL', 'YEAR'])['ADJCLOSE']

# Calculate Daily Return
hist_data['DAILYRETURN'] = adj_close_by_symbol.transform(lambda x: x.pct_change() * 100)

#Group by Symbol and Year, Date with Daily Return
daily_returns_by_year_symbol = hist_data.groupby(['SYMBOL', 'YEAR'])['DAILYRETURN']
daily_returns_by_year_month_symbol = hist_data.groupby(['SYMBOL', 'YEAR','MONTH'])['DAILYRETURN']

# Calculate Cummulative return
hist_data['CUMMULATIVERETURN'] = daily_returns_by_year_month_symbol.transform(lambda x: (1 + x / 100).cumprod() - 1)

# Define rolling periods
rolling_periods = [30, 90]

# Calculate rolling returns for each defined period
for period in rolling_periods:
    hist_data[f'ROLLINGRETURN{period}'] = adj_close_by_symbol.transform(lambda x: x.pct_change(periods=period).rolling(window=period).sum())

# Calculate Sharpe ratio for each symbol
risk_free_rate = 0  # assuming risk-free rate is 0 for simplicity

# Calculate Sharpe Ratio using transform
hist_data['SHARPERATIO'] = daily_returns_by_year_symbol.transform(lambda x: (x.mean() - risk_free_rate) / x.std() * np.sqrt(252))

# Drop the 'YEAR' & 'MONTH' newly created column for Calculation
hist_data.drop(columns=['YEAR','MONTH'], inplace=True)

# %%
#Validation of Historical records after the inclusion of new columns
hist_data.head(100)
# Out:
#     STOCKDATE        OPEN        HIGH         LOW       CLOSE    ADJCLOSE  \
# 0  2021-01-04  266.709991  267.290009  257.369995  258.809998  246.256989
# 1  2021-01-05  257.559998  263.239990  257.559998  262.869995  250.120056
# 2  2021-01-06  261.399994  274.579987  261.390015  271.500000  258.331482
# 3  2021-01-07  269.059998  273.760010  269.000000  270.720001  257.589355
# 4  2021-01-08  272.029999  272.380005  267.929993  270.399994  257.284882
# ..        ...         ...         ...         ...         ...         ...
# 95 2021-05-20  297.510010  300.820007  297.510010  298.130005  284.889771
# 96 2021-05-21  299.739990  302.029999  298.339996  298.570007  285.310242
# 97 2021-05-24  301.149994  303.070007  300.549988  301.269989  287.890289
# 98 2021-05-25  302.410004  302.690002  300.220001  301.250000  287.871246
# 99 2021-05-26  301.100006  301.589996  297.459991  299.769989  286.456909
#
#      VOLUME SYMBOL  DAILYRETURN  CUMMULATIVERETURN  ROLLINGRETURN30  \
# 0   1741300    LIN          NaN                NaN              NaN
# 1   1620000    LIN     1.568714           0.015687              NaN
# 2   2586600    LIN     3.282994           0.049032              NaN
# 3   1757800    LIN    -0.287277           0.046018              NaN
# 4   1879300    LIN    -0.118201           0.044782              NaN
# ..      ...    ...          ...                ...              ...
# 95  1272900    LIN     0.695768           0.042996         2.824626
# 96  1923500    LIN     0.147591           0.044535         2.714981
# 97  1058300    LIN     0.904295           0.053981         2.596949
# 98  1330300    LIN    -0.006615           0.053911         2.505933
# 99  1411600    LIN    -0.491309           0.048734         2.430548
#
#     ROLLINGRETURN90  SHARPERATIO
# 0               NaN     1.489823
# 1               NaN     1.489823
# 2               NaN     1.489823
# 3               NaN     1.489823
# 4               NaN     1.489823
# ..              ...          ...
# 95              NaN     1.489823
# 96              NaN     1.489823
# 97              NaN     1.489823
# 98              NaN     1.489823
# 99              NaN     1.489823
#
# [100 rows x 13 columns]

# %%
from sqlalchemy import create_engine,text

#Create Engine to load data to data warehouse table
engine = create_engine('oracle://"dss_stock":stock@localhost:1521/?service_name=ORCL')

with engine.connect() as connection:
    connection.execute(text("TRUNCATE TABLE stock_history"))
    connection.commit()

#Load data to the Data warehouse Table
try:
    hist_data.to_sql('stock_history', con=engine, if_exists='append', index=False)
    print("Data insertion successful.")
except Exception as e:
    print(f"Error inserting data: {str(e)}")
# Out:
# Data insertion successful.

# %%
import requests

# Add Alpha Vantage API key - Since requests are limited with free account to interchange, created two accounts
api_key = 'SN3GKHZJU3LXYLI7'
#api_key = 'SQXUEHCZJNVRJFMG'

# Initialize an empty list to store dataframes
articles_df = []

# Iterate through each ticker symbol
for symbol in ticker_symbols:
    # Define the API endpoint and parameters
    url = f'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers={symbol}&apikey={api_key}'
    print(url)
    
    # Make the request to Alpha Vantage API
    response = requests.get(url)
    
    # Check if the request was successful
    if response.status_code == 200:
        data = response.json()
        
        # Extract the news articles data
        if 'feed' in data and data['feed'] is not None:
            articles = data['feed']
        else:
            articles = None  # Handle the case where feed data is not available
        
        # Convert the articles data to a DataFrame
        if articles:
            news_df = pd.DataFrame(articles)
            news_df['ticker'] = symbol
            
            # Convert 'time_published' to datetime format and filter by date
            news_df['time_published'] = pd.to_datetime(news_df['time_published'], format='%Y%m%dT%H%M%S')
            
            #Consider news relevant only for the specified tickers if they are dated before 2021
            news_df = news_df[news_df['time_published'].dt.year > 2021]
            
            # Append the DataFrame to the list
            articles_df.append(news_df)
        else:
            print(f"No news articles found for symbol {symbol}")
    else:
        print(f"Failed to fetch news articles for symbol {symbol}. Status code: {response.status_code}")

# Concatenate all DataFrames into one
if articles_df:
    articles_data = pd.concat(articles_df, ignore_index=True)
    
    # Display the concatenated DataFrame
    print(articles_data)
else:
    print("No data fetched for any symbol.")
# Out:
# https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=LIN&apikey=SN3GKHZJU3LXYLI7
# https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=MRK&apikey=SN3GKHZJU3LXYLI7
# No news articles found for symbol MRK
# https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AIR&apikey=SN3GKHZJU3LXYLI7
# No news articles found for symbol AIR
# https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=BNR&apikey=SN3GKHZJU3LXYLI7
# No news articles found for symbol BNR
# https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=MTX&apikey=SN3GKHZJU3LXYLI7
# No news articles found for symbol MTX
# https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=ENR&apikey=SN3GKHZJU3LXYLI7
# No news articles found for symbol ENR
# https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=DTG&apikey=SN3GKHZJU3LXYLI7
# No news articles found for symbol DTG
# https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=MBG&apikey=SN3GKHZJU3LXYLI7
# No news articles found for symbol MBG
#                                                 title  \
# 0   Electronic Wet Chemicals Market worth $5.4 bil...
# 1   $100 Invested In This Stock 5 Years Ago Would ...
# 2   Linde Unusual Options Activity For June 27 - L...
# 3   Should You Invest in the iShares U.S. Basic Ma...
# 4   If You Invested $1000 In This Stock 20 Years A...
# 5   The Zacks Analyst Blog Highlights NVIDIA, Tesl...
# 6         Top Stock Reports for NVIDIA, Tesla & Linde
# 7   Here's How Much You Would Have Made Owning Lin...
# 8   Should You Invest in the Materials Select Sect...
# 9   Should You Invest in the Materials Select Sect...
# 10  The 145-Year-Old Giant Bringing Greener Hydrog...
# 11  Should You Invest in the Vanguard Materials ET...
# 12  Here's How Much You Would Have Made Owning Lin...
# 13  The $1.7 Billion News That Sent Plug Power Sto...
# 14  Should You Invest in the Fidelity MSCI Materia...
# 15  The Zacks Analyst Blog Highlights Apple, Linde...
# 16    Top Research Reports for Apple, Linde & Comcast
# 17  Here's a point-by-point rundown on why we're b...
# 18  A Closer Look at Linde's Options Market Dynami...
# 19  We're buying 2 unfairly punished stocks and 1 ...
# 20  Linde's  ( LIN )  Q1 Earnings Beat Estimates o...
# 21         Linde  ( LIN )  Tops Q1 Earnings Estimates
# 22  Methanex Trying To Close In On Key Technical M...
# 23  Are Basic Materials Stocks Lagging Linde PLC  ...
# 24  Linde  ( LIN )  Gears up to Report Q1 Earnings...
# 25  Curious about Linde  ( LIN )  Q1 Performance? ...
# 26  U.S. Silica Holdings Shows Rising Price Perfor...
# 27  Linde  ( LIN )  Stock Slides as Market Rises: ...
# 28  Blachem  ( BCPC )  Reports Next Week: Wall Str...
# 29      2 Hydrogen Stocks To Watch In Late-April 2024
# 30  Linde  ( LIN )  Earnings Expected to Grow: Wha...
# 31  Should You Invest in the iShares U.S. Basic Ma...
# 32  When Tesla Dips, These Six S&P 500 Stocks Incl...
# 33  The U.S. Is About to Spend Hundreds of Billion...
# 34  Will Materials ETFs Gain Further as Q1 Earning...
# 35  Unpacking the Latest Options Trading Trends in...
# 36  The Zacks Analyst Blog Highlights Eli Lilly, L...
# 37  $1000 Invested In Linde 20 Years Ago Would Be ...
# 38  All You Need to Know About Linde  ( LIN )  Rat...
# 39  Are Basic Materials Stocks Lagging DRDGOLD Lim...
# 40  Here's why we disagree with Citigroup's downgr...
# 41                    Balchem Earns RS Rating Upgrade
# 42  Step Aside, Growth Stocks. Value Is Poised for...
# 43  Stocks Flashing Renewed Technical Strength: Mi...
# 44  Linde  ( LIN )  Stock Moves -0.2%: What You Sh...
# 45  If You Invested $100 In This Stock 10 Years Ag...
# 46  The Zacks Analyst Blog Highlights Walmart, Lin...
# 47  Wall Street Analysts Think Linde  ( LIN )  Is ...
# 48      Top Research Reports for Walmart, Linde & IBM
# 49  H.B. Fuller Earns Relative Strength Rating Upg...
#
#                                                   url      time_published  \
# 0   https://www.benzinga.com/pressreleases/24/07/g... 2024-07-04 10:30:00
# 1   https://www.benzinga.com/insights/news/24/07/3... 2024-07-03 14:00:47
# 2   https://www.benzinga.com/insights/options/24/0... 2024-06-27 19:01:56
# 3   https://www.zacks.com/stock/news/2292622/shoul... 2024-06-25 10:20:07
# 4   https://www.benzinga.com/insights/news/24/06/3... 2024-06-21 21:30:56
# 5   https://www.zacks.com/stock/news/2285100/the-z... 2024-06-07 09:42:00
# 6   https://www.zacks.com/research-daily/2284773/t... 2024-06-06 17:59:00
# 7   https://www.benzinga.com/insights/news/24/05/3... 2024-05-31 21:30:30
# 8   https://www.benzinga.com/news/24/05/39059719/s... 2024-05-30 17:11:30
# 9   https://www.zacks.com/stock/news/2280351/shoul... 2024-05-29 10:20:06
# 10  https://www.forbes.com/sites/baldwin/2024/05/2... 2024-05-21 10:30:00
# 11  https://www.zacks.com/stock/news/2276379/shoul... 2024-05-21 10:20:08
# 12  https://www.benzinga.com/insights/news/24/05/3... 2024-05-17 14:30:14
# 13  https://www.fool.com/investing/2024/05/14/the-... 2024-05-14 20:16:19
# 14  https://www.zacks.com/stock/news/2272536/shoul... 2024-05-13 10:20:05
# 15  https://www.zacks.com/stock/news/2269215/the-z... 2024-05-07 09:34:00
# 16  https://www.zacks.com/research-daily/2268535/t... 2024-05-06 16:18:00
# 17  https://www.cnbc.com/2024/05/02/heres-a-rundow... 2024-05-02 16:39:26
# 18  https://www.benzinga.com/insights/options/24/0... 2024-05-02 15:32:07
# 19  https://www.cnbc.com/2024/05/02/were-going-on-... 2024-05-02 15:15:45
# 20  https://www.zacks.com/stock/news/2267255/linde... 2024-05-02 14:39:00
# 21  https://www.zacks.com/stock/news/2266632/linde... 2024-05-02 11:05:02
# 22  https://www.investors.com/ibd-data-stories/met... 2024-05-02 07:00:00
# 23  https://www.zacks.com/stock/news/2265931/are-b... 2024-05-01 13:40:12
# 24  https://www.zacks.com/stock/news/2264744/linde... 2024-04-30 11:48:00
# 25  https://www.zacks.com/stock/news/2263986/curio... 2024-04-29 13:16:08
# 26  https://www.investors.com/ibd-data-stories/u-s... 2024-04-29 07:00:00
# 27  https://www.zacks.com/stock/news/2263683/linde... 2024-04-26 22:15:11
# 28  https://www.zacks.com/stock/news/2263357/blach... 2024-04-26 14:00:26
# 29  https://stockmarket.com/featured/2-hydrogen-st... 2024-04-25 14:05:42
# 30  https://www.zacks.com/stock/news/2262314/linde... 2024-04-25 14:02:11
# 31  https://www.zacks.com/stock/news/2260773/shoul... 2024-04-24 10:20:06
# 32  https://www.benzinga.com/markets/equities/24/0... 2024-04-23 08:46:33
# 33  https://www.fool.com/investing/2024/04/21/us-s... 2024-04-21 09:15:00
# 34  https://www.zacks.com/stock/news/2257915/will-... 2024-04-18 16:00:00
# 35  https://www.benzinga.com/insights/options/24/0... 2024-04-18 15:34:08
# 36  https://www.zacks.com/stock/news/2257331/the-z... 2024-04-18 08:20:00
# 37  https://www.benzinga.com/insights/news/24/04/3... 2024-04-17 16:00:32
# 38  https://www.zacks.com/stock/news/2255527/all-y... 2024-04-15 16:00:10
# 39  https://www.zacks.com/stock/news/2255263/are-b... 2024-04-15 13:40:10
# 40  https://www.cnbc.com/2024/04/10/we-disagree-wi... 2024-04-10 15:57:09
# 41  https://www.investors.com/ibd-data-stories/bal... 2024-04-09 07:00:00
# 42  https://www.barrons.com/amp/articles/value-gro... 2024-04-09 05:30:00
# 43  https://www.investors.com/ibd-data-stories/sto... 2024-04-03 07:00:00
# 44  https://www.zacks.com/stock/news/2248751/linde... 2024-04-01 22:15:19
# 45  https://www.benzinga.com/insights/news/24/04/3... 2024-04-01 21:30:26
# 46  https://www.zacks.com/stock/news/2248151/the-z... 2024-04-01 11:17:00
# 47  https://www.zacks.com/stock/news/2247866/wall-... 2024-03-29 13:30:11
# 48  https://www.zacks.com/research-daily/2247419/t... 2024-03-28 20:15:00
# 49  https://www.investors.com/ibd-data-stories/h-b... 2024-03-28 08:00:00
#
#                                               authors  \
# 0                                    [Globe Newswire]
# 1                                 [Benzinga Insights]
# 2                                 [Benzinga Insights]
# 3                             [Zacks Equity Research]
# 4                                 [Benzinga Insights]
# 5                             [Zacks Equity Research]
# 6                                       [Sheraz Mian]
# 7                                 [Benzinga Insights]
# 8                                             [Zacks]
# 9                             [Zacks Equity Research]
# 10                                  [William Baldwin]
# 11                            [Zacks Equity Research]
# 12                                [Benzinga Insights]
# 13                       [Jason Hall and Tyler Crowe]
# 14                            [Zacks Equity Research]
# 15                            [Zacks Equity Research]
# 16                                      [Sheraz Mian]
# 17                                         [Zev Fima]
# 18                                [Benzinga Insights]
# 19                                   [Morgan Chittum]
# 20                            [Zacks Equity Research]
# 21                            [Zacks Equity Research]
# 22  [Investor's Business Daily, INVESTOR'S BUSINES...
# 23                            [Zacks Equity Research]
# 24                            [Zacks Equity Research]
# 25                            [Zacks Equity Research]
# 26  [Investor's Business Daily, INVESTOR'S BUSINES...
# 27                            [Zacks Equity Research]
# 28                            [Zacks Equity Research]
# 29                                 [Jonathan Phillip]
# 30                            [Zacks Equity Research]
# 31                            [Zacks Equity Research]
# 32                                   [Benzinga Neuro]
# 33                                 [Billy Duberstein]
# 34                                      [Sweta Killa]
# 35                                [Benzinga Insights]
# 36                        [Zacks Investment Research]
# 37                                [Benzinga Insights]
# 38                            [Zacks Equity Research]
# 39                            [Zacks Equity Research]
# 40                                   [Morgan Chittum]
# 41  [INVESTOR'S BUSINESS DAILY, Investor's Busines...
# 42                                   [Reshma Kapadia]
# 43  [Investor's Business Daily, INVESTOR'S BUSINES...
# 44                            [Zacks Equity Research]
# 45                                [Benzinga Insights]
# 46                        [Zacks Investment Research]
# 47                            [Zacks Equity Research]
# 48                                     [Mark Vickery]
# 49  [INVESTOR'S BUSINESS DAILY, Investor's Busines...
#
#                                               summary  \
# 0   Chicago, July 04, 2024 ( GLOBE NEWSWIRE ) -- T...
# 1   Linde LIN has outperformed the market over the...
# 2   Investors with a lot of money to spend have ta...
# 3                           Sector ETF report for ...
# 4   Linde LIN has outperformed the market over the...
# 5   NVIDIA, Tesla, Linde, Servotronics and The Cat...
# 6   Today's Research Daily features new research r...
# 7   Linde LIN has outperformed the market over the...
# 8   Looking for broad exposure to the Materials - ...
# 9                           Sector ETF report for ...
# 10  Sanjiv Lamba, CEO of industrial gas producer L...
# 11                      Sector ETF report for VAW ...
# 12  Linde LIN has outperformed the market over the...
# 13  More cash will solve some problems, but maybe ...
# 14                          Sector ETF report for ...
# 15  Apple, Linde, Comcast, ICICI Bank and Xylem ar...
# 16  Today's Research Daily features new research r...
# 17  With this trade, we are upgrading LIN and TJX ...
# 18  Investors with a lot of money to spend have ta...
# 19  The Investing Club holds its "Morning Meeting"...
# 20  Higher pricing from the Americas segment aids ...
# 21  Linde (LIN) delivered earnings and revenue sur...
# 22  The Relative Strength ( RS ) Rating for Methan...
# 23  Here is how Linde (LIN) and Steel Dynamics (ST...
# 24  Linde's (LIN) Q1 earnings are likely to have b...
# 25  Beyond analysts' top -and-bottom-line estimate...
# 26  U.S. Silica Holdings ( SLCA ) saw a welcome im...
# 27  In the most recent trading session, Linde (LIN...
# 28  Blachem (BCPC) doesn't possess the right combi...
# 29  The hydrogen sector is gaining traction as a k...
# 30  Linde (LIN) doesn't possess the right combinat...
# 31                          Sector ETF report for ...
# 32  In a recent turn of events, shares of Tesla In...
# 33  Most funds from the 2021 infrastructure bill h...
# 34  Going into the Q1 earnings season, earnings re...
# 35  Deep-pocketed investors have adopted a bullish...
# 36  Eli Lilly, Linde, Caterpillar, Salesforce, and...
# 37  Linde LIN has outperformed the market over the...
# 38  Linde (LIN) has been upgraded to a Zacks Rank ...
# 39  Here is how DRDGOLD (DRD) and Linde (LIN) have...
# 40  The Investing Club holds its "Morning Meeting"...
# 41  Balchem ( BCPC ) had its Relative Strength ( R...
# 42  Value Stocks Are Poised for a Comeback. 5 Winn...
# 43  When considering what names to put on your wat...
# 44  The latest trading day saw Linde (LIN) settlin...
# 45  Linde LIN has outperformed the market over the...
# 46  Walmart, Linde, IBM, Deere and Duke Energy are...
# 47  According to the average brokerage recommendat...
# 48  Today's Research Daily features new research r...
# 49  In a welcome move, H.B. Fuller ( FUL ) saw its...
#
#                                          banner_image  \
# 0   https://www.benzinga.com/next-assets/images/sc...
# 1   https://cdn.benzinga.com/files/images/story/20...
# 2   https://cdn.benzinga.com/files/images/story/20...
# 3   https://staticx-tuner.zacks.com/images/default...
# 4   https://cdn.benzinga.com/files/images/story/20...
# 5   https://staticx-tuner.zacks.com/images/article...
# 6   https://staticx-tuner.zacks.com/images/default...
# 7   https://cdn.benzinga.com/files/images/story/20...
# 8   https://cdn.benzinga.com/files/images/story/20...
# 9   https://staticx-tuner.zacks.com/images/default...
# 10  https://imageio.forbes.com/specials-images/ima...
# 11  https://staticx-tuner.zacks.com/images/default...
# 12  https://cdn.benzinga.com/files/images/story/20...
# 13  https://g.foolcdn.com/editorial/images/777355/...
# 14  https://staticx-tuner.zacks.com/images/default...
# 15  https://staticx-tuner.zacks.com/images/article...
# 16  https://staticx-tuner.zacks.com/images/default...
# 17  https://image.cnbcfm.com/api/v1/image/10723425...
# 18  https://cdn.benzinga.com/files/images/story/20...
# 19  https://image.cnbcfm.com/api/v1/image/10737718...
# 20  https://staticx-tuner.zacks.com/images/article...
# 21  https://staticx-tuner.zacks.com/images/default...
# 22  https://www.investors.com/wp-content/uploads/2...
# 23  https://staticx-tuner.zacks.com/images/default...
# 24  https://staticx-tuner.zacks.com/images/article...
# 25  https://staticx-tuner.zacks.com/images/default...
# 26  https://www.investors.com/wp-content/uploads/2...
# 27  https://staticx-tuner.zacks.com/images/default...
# 28  https://staticx-tuner.zacks.com/images/default...
# 29  https://u3j7m9h7.rocketcdn.me/wp-content/uploa...
# 30  https://staticx-tuner.zacks.com/images/default...
# 31  https://staticx-tuner.zacks.com/images/default...
# 32  https://cdn.benzinga.com/files/images/story/20...
# 33  https://g.foolcdn.com/image/?url=https%3A%2F%2...
# 34  https://staticx-tuner.zacks.com/images/default...
# 35  https://cdn.benzinga.com/files/images/story/20...
# 36  https://staticx-tuner.zacks.com/images/article...
# 37  https://cdn.benzinga.com/files/images/story/20...
# 38  https://staticx-tuner.zacks.com/images/default...
# 39  https://staticx-tuner.zacks.com/images/default...
# 40  https://image.cnbcfm.com/api/v1/image/10725777...
# 41  https://www.investors.com/wp-content/uploads/2...
# 42      https://images.barrons.com/im-71342103/social
# 43  https://www.investors.com/wp-content/uploads/2...
# 44  https://staticx-tuner.zacks.com/images/default...
# 45  https://cdn.benzinga.com/files/images/story/20...
# 46  https://staticx-tuner.zacks.com/images/article...
# 47  https://staticx-tuner.zacks.com/images/default...
# 48  https://staticx-tuner.zacks.com/images/article...
# 49  https://www.investors.com/wp-content/uploads/2...
#
#                       source category_within_source      source_domain  \
# 0                   Benzinga                   News   www.benzinga.com
# 1                   Benzinga                Trading   www.benzinga.com
# 2                   Benzinga                Markets   www.benzinga.com
# 3           Zacks Commentary                    n/a      www.zacks.com
# 4                   Benzinga                Trading   www.benzinga.com
# 5           Zacks Commentary                    n/a      www.zacks.com
# 6           Zacks Commentary                    n/a      www.zacks.com
# 7                   Benzinga                Trading   www.benzinga.com
# 8                   Benzinga                Trading   www.benzinga.com
# 9           Zacks Commentary                    n/a      www.zacks.com
# 10                    Forbes                    n/a     www.forbes.com
# 11          Zacks Commentary                    n/a      www.zacks.com
# 12                  Benzinga                Trading   www.benzinga.com
# 13               Motley Fool                    n/a       www.fool.com
# 14          Zacks Commentary                    n/a      www.zacks.com
# 15          Zacks Commentary                    n/a      www.zacks.com
# 16          Zacks Commentary                    n/a      www.zacks.com
# 17                      CNBC               Top News       www.cnbc.com
# 18                  Benzinga                Markets   www.benzinga.com
# 19                      CNBC               Earnings       www.cnbc.com
# 20          Zacks Commentary                    n/a      www.zacks.com
# 21          Zacks Commentary                    n/a      www.zacks.com
# 22  Investors Business Daily                    n/a  www.investors.com
# 23          Zacks Commentary                    n/a      www.zacks.com
# 24          Zacks Commentary                    n/a      www.zacks.com
# 25          Zacks Commentary                    n/a      www.zacks.com
# 26  Investors Business Daily                    n/a  www.investors.com
# 27          Zacks Commentary                    n/a      www.zacks.com
# 28          Zacks Commentary                    n/a      www.zacks.com
# 29           StockMarket.com                    n/a    stockmarket.com
# 30          Zacks Commentary                    n/a      www.zacks.com
# 31          Zacks Commentary                    n/a      www.zacks.com
# 32                  Benzinga                General   www.benzinga.com
# 33               Motley Fool                    n/a       www.fool.com
# 34          Zacks Commentary                    n/a      www.zacks.com
# 35                  Benzinga                Markets   www.benzinga.com
# 36          Zacks Commentary                    n/a      www.zacks.com
# 37                  Benzinga                Trading   www.benzinga.com
# 38          Zacks Commentary                    n/a      www.zacks.com
# 39          Zacks Commentary                    n/a      www.zacks.com
# 40                      CNBC               Top News       www.cnbc.com
# 41  Investors Business Daily                    n/a  www.investors.com
# 42                   Barrons                    n/a    www.barrons.com
# 43  Investors Business Daily                    n/a  www.investors.com
# 44          Zacks Commentary                    n/a      www.zacks.com
# 45                  Benzinga                Trading   www.benzinga.com
# 46          Zacks Commentary                    n/a      www.zacks.com
# 47          Zacks Commentary                    n/a      www.zacks.com
# 48          Zacks Commentary                    n/a      www.zacks.com
# 49  Investors Business Daily                    n/a  www.investors.com
#
#                                                topics  \
# 0   [{'topic': 'Life Sciences', 'relevance_score':...
# 1   [{'topic': 'Life Sciences', 'relevance_score':...
# 2   [{'topic': 'Earnings', 'relevance_score': '0.3...
# 3   [{'topic': 'Life Sciences', 'relevance_score':...
# 4   [{'topic': 'Life Sciences', 'relevance_score':...
# 5   [{'topic': 'Life Sciences', 'relevance_score':...
# 6   [{'topic': 'Earnings', 'relevance_score': '0.8...
# 7   [{'topic': 'Life Sciences', 'relevance_score':...
# 8   [{'topic': 'Life Sciences', 'relevance_score':...
# 9   [{'topic': 'Life Sciences', 'relevance_score':...
# 10  [{'topic': 'Life Sciences', 'relevance_score':...
# 11  [{'topic': 'Life Sciences', 'relevance_score':...
# 12  [{'topic': 'Life Sciences', 'relevance_score':...
# 13  [{'topic': 'Life Sciences', 'relevance_score':...
# 14  [{'topic': 'Life Sciences', 'relevance_score':...
# 15  [{'topic': 'Life Sciences', 'relevance_score':...
# 16  [{'topic': 'Earnings', 'relevance_score': '0.1...
# 17  [{'topic': 'Life Sciences', 'relevance_score':...
# 18  [{'topic': 'Life Sciences', 'relevance_score':...
# 19  [{'topic': 'Life Sciences', 'relevance_score':...
# 20  [{'topic': 'Earnings', 'relevance_score': '0.9...
# 21  [{'topic': 'Earnings', 'relevance_score': '0.9...
# 22  [{'topic': 'Life Sciences', 'relevance_score':...
# 23  [{'topic': 'Life Sciences', 'relevance_score':...
# 24  [{'topic': 'Life Sciences', 'relevance_score':...
# 25  [{'topic': 'Earnings', 'relevance_score': '0.9...
# 26  [{'topic': 'Life Sciences', 'relevance_score':...
# 27  [{'topic': 'Earnings', 'relevance_score': '0.9...
# 28  [{'topic': 'Earnings', 'relevance_score': '1.0...
# 29  [{'topic': 'Life Sciences', 'relevance_score':...
# 30  [{'topic': 'Earnings', 'relevance_score': '1.0...
# 31  [{'topic': 'Life Sciences', 'relevance_score':...
# 32  [{'topic': 'Life Sciences', 'relevance_score':...
# 33  [{'topic': 'Life Sciences', 'relevance_score':...
# 34  [{'topic': 'Economy - Monetary', 'relevance_sc...
# 35  [{'topic': 'Life Sciences', 'relevance_score':...
# 36  [{'topic': 'Life Sciences', 'relevance_score':...
# 37  [{'topic': 'Life Sciences', 'relevance_score':...
# 38  [{'topic': 'Earnings', 'relevance_score': '0.9...
# 39  [{'topic': 'Life Sciences', 'relevance_score':...
# 40  [{'topic': 'Economy - Monetary', 'relevance_sc...
# 41  [{'topic': 'Earnings', 'relevance_score': '0.3...
# 42  [{'topic': 'Economy - Monetary', 'relevance_sc...
# 43  [{'topic': 'Life Sciences', 'relevance_score':...
# 44  [{'topic': 'Earnings', 'relevance_score': '0.9...
# 45  [{'topic': 'Life Sciences', 'relevance_score':...
# 46  [{'topic': 'Life Sciences', 'relevance_score':...
# 47  [{'topic': 'Earnings', 'relevance_score': '0.8...
# 48  [{'topic': 'Economy - Monetary', 'relevance_sc...
# 49  [{'topic': 'Earnings', 'relevance_score': '0.3...
#
#     overall_sentiment_score overall_sentiment_label  \
# 0                  0.266982        Somewhat-Bullish
# 1                  0.238974        Somewhat-Bullish
# 2                  0.175175        Somewhat-Bullish
# 3                  0.170745        Somewhat-Bullish
# 4                  0.238974        Somewhat-Bullish
# 5                  0.319607        Somewhat-Bullish
# 6                  0.364505                 Bullish
# 7                  0.238974        Somewhat-Bullish
# 8                  0.221215        Somewhat-Bullish
# 9                  0.195587        Somewhat-Bullish
# 10                 0.094835                 Neutral
# 11                 0.202422        Somewhat-Bullish
# 12                 0.238974        Somewhat-Bullish
# 13                 0.077904                 Neutral
# 14                 0.211995        Somewhat-Bullish
# 15                 0.192374        Somewhat-Bullish
# 16                 0.272576        Somewhat-Bullish
# 17                 0.257252        Somewhat-Bullish
# 18                 0.136670                 Neutral
# 19                 0.196242        Somewhat-Bullish
# 20                 0.244207        Somewhat-Bullish
# 21                 0.193779        Somewhat-Bullish
# 22                 0.287903        Somewhat-Bullish
# 23                 0.179921        Somewhat-Bullish
# 24                 0.179803        Somewhat-Bullish
# 25                 0.226728        Somewhat-Bullish
# 26                 0.323637        Somewhat-Bullish
# 27                 0.165503        Somewhat-Bullish
# 28                 0.149636                 Neutral
# 29                 0.354311                 Bullish
# 30                 0.133393                 Neutral
# 31                 0.188862        Somewhat-Bullish
# 32                 0.076079                 Neutral
# 33                 0.198467        Somewhat-Bullish
# 34                 0.179797        Somewhat-Bullish
# 35                 0.159382        Somewhat-Bullish
# 36                 0.172806        Somewhat-Bullish
# 37                 0.238974        Somewhat-Bullish
# 38                 0.309570        Somewhat-Bullish
# 39                 0.248692        Somewhat-Bullish
# 40                 0.036692                 Neutral
# 41                 0.307158        Somewhat-Bullish
# 42                 0.357524                 Bullish
# 43                 0.321911        Somewhat-Bullish
# 44                 0.197035        Somewhat-Bullish
# 45                 0.238974        Somewhat-Bullish
# 46                 0.303960        Somewhat-Bullish
# 47                 0.273581        Somewhat-Bullish
# 48                 0.370743                 Bullish
# 49                 0.351409                 Bullish
#
#                                      ticker_sentiment ticker
# 0   [{'ticker': 'LIN', 'relevance_score': '0.02782...    LIN
# 1   [{'ticker': 'LIN', 'relevance_score': '0.95919...    LIN
# 2   [{'ticker': 'LIN', 'relevance_score': '0.74780...    LIN
# 3   [{'ticker': 'BLK', 'relevance_score': '0.06550...    LIN
# 4   [{'ticker': 'LIN', 'relevance_score': '0.95919...    LIN
# 5   [{'ticker': 'LIN', 'relevance_score': '0.16997...    LIN
# 6   [{'ticker': 'LIN', 'relevance_score': '0.05257...    LIN
# 7   [{'ticker': 'LIN', 'relevance_score': '0.95919...    LIN
# 8   [{'ticker': 'LIN', 'relevance_score': '0.13459...    LIN
# 9   [{'ticker': 'LIN', 'relevance_score': '0.13057...    LIN
# 10  [{'ticker': 'LIN', 'relevance_score': '0.02288...    LIN
# 11  [{'ticker': 'LIN', 'relevance_score': '0.13459...    LIN
# 12  [{'ticker': 'LIN', 'relevance_score': '0.95919...    LIN
# 13  [{'ticker': 'LIN', 'relevance_score': '0.76059...    LIN
# 14  [{'ticker': 'LIN', 'relevance_score': '0.13273...    LIN
# 15  [{'ticker': 'LIN', 'relevance_score': '0.40784...    LIN
# 16  [{'ticker': 'LIN', 'relevance_score': '0.26018...    LIN
# 17  [{'ticker': 'LIN', 'relevance_score': '0.41005...    LIN
# 18  [{'ticker': 'LIN', 'relevance_score': '0.74813...    LIN
# 19  [{'ticker': 'LIN', 'relevance_score': '0.17845...    LIN
# 20  [{'ticker': 'LIN', 'relevance_score': '0.56671...    LIN
# 21  [{'ticker': 'LIN', 'relevance_score': '0.40894...    LIN
# 22  [{'ticker': 'LIN', 'relevance_score': '0.38292...    LIN
# 23  [{'ticker': 'LIN', 'relevance_score': '0.73941...    LIN
# 24  [{'ticker': 'GIC', 'relevance_score': '0.07010...    LIN
# 25  [{'ticker': 'LIN', 'relevance_score': '0.41592...    LIN
# 26  [{'ticker': 'CBT', 'relevance_score': '0.32955...    LIN
# 27  [{'ticker': 'LIN', 'relevance_score': '0.58568...    LIN
# 28  [{'ticker': 'LIN', 'relevance_score': '0.17585...    LIN
# 29  [{'ticker': 'GIC', 'relevance_score': '0.06497...    LIN
# 30  [{'ticker': 'LIN', 'relevance_score': '0.25835...    LIN
# 31  [{'ticker': 'BLK', 'relevance_score': '0.06586...    LIN
# 32  [{'ticker': 'LIN', 'relevance_score': '0.19903...    LIN
# 33  [{'ticker': 'LIN', 'relevance_score': '0.20900...    LIN
# 34  [{'ticker': 'LIN', 'relevance_score': '0.12013...    LIN
# 35  [{'ticker': 'LIN', 'relevance_score': '0.77273...    LIN
# 36  [{'ticker': 'LIN', 'relevance_score': '0.21304...    LIN
# 37  [{'ticker': 'LIN', 'relevance_score': '0.95919...    LIN
# 38  [{'ticker': 'LIN', 'relevance_score': '0.36968...    LIN
# 39  [{'ticker': 'LIN', 'relevance_score': '0.39346...    LIN
# 40  [{'ticker': 'LIN', 'relevance_score': '0.23430...    LIN
# 41  [{'ticker': 'LIN', 'relevance_score': '0.33858...    LIN
# 42  [{'ticker': 'LIN', 'relevance_score': '0.05978...    LIN
# 43  [{'ticker': 'LIN', 'relevance_score': '0.30505...    LIN
# 44  [{'ticker': 'LIN', 'relevance_score': '0.52949...    LIN
# 45  [{'ticker': 'LIN', 'relevance_score': '0.95919...    LIN
# 46  [{'ticker': 'LIN', 'relevance_score': '0.41342...    LIN
# 47  [{'ticker': 'LIN', 'relevance_score': '0.36075...    LIN
# 48  [{'ticker': 'LIN', 'relevance_score': '0.27177...    LIN
# 49  [{'ticker': 'CBT', 'relevance_score': '0.33628...    LIN

# %%
#Validation of Articles
articles_data.head()
# Out:
#                                                title  \
# 0  Electronic Wet Chemicals Market worth $5.4 bil...
# 1  $100 Invested In This Stock 5 Years Ago Would ...
# 2  Linde Unusual Options Activity For June 27 - L...
# 3  Should You Invest in the iShares U.S. Basic Ma...
# 4  If You Invested $1000 In This Stock 20 Years A...
#
#                                                  url      time_published  \
# 0  https://www.benzinga.com/pressreleases/24/07/g... 2024-07-04 10:30:00
# 1  https://www.benzinga.com/insights/news/24/07/3... 2024-07-03 14:00:47
# 2  https://www.benzinga.com/insights/options/24/0... 2024-06-27 19:01:56
# 3  https://www.zacks.com/stock/news/2292622/shoul... 2024-06-25 10:20:07
# 4  https://www.benzinga.com/insights/news/24/06/3... 2024-06-21 21:30:56
#
#                    authors                                            summary  \
# 0         [Globe Newswire]  Chicago, July 04, 2024 ( GLOBE NEWSWIRE ) -- T...
# 1      [Benzinga Insights]  Linde LIN has outperformed the market over the...
# 2      [Benzinga Insights]  Investors with a lot of money to spend have ta...
# 3  [Zacks Equity Research]                          Sector ETF report for ...
# 4      [Benzinga Insights]  Linde LIN has outperformed the market over the...
#
#                                         banner_image            source  \
# 0  https://www.benzinga.com/next-assets/images/sc...          Benzinga
# 1  https://cdn.benzinga.com/files/images/story/20...          Benzinga
# 2  https://cdn.benzinga.com/files/images/story/20...          Benzinga
# 3  https://staticx-tuner.zacks.com/images/default...  Zacks Commentary
# 4  https://cdn.benzinga.com/files/images/story/20...          Benzinga
#
#   category_within_source     source_domain  \
# 0                   News  www.benzinga.com
# 1                Trading  www.benzinga.com
# 2                Markets  www.benzinga.com
# 3                    n/a     www.zacks.com
# 4                Trading  www.benzinga.com
#
#                                               topics  overall_sentiment_score  \
# 0  [{'topic': 'Life Sciences', 'relevance_score':...                 0.266982
# 1  [{'topic': 'Life Sciences', 'relevance_score':...                 0.238974
# 2  [{'topic': 'Earnings', 'relevance_score': '0.3...                 0.175175
# 3  [{'topic': 'Life Sciences', 'relevance_score':...                 0.170745
# 4  [{'topic': 'Life Sciences', 'relevance_score':...                 0.238974
#
#   overall_sentiment_label                                   ticker_sentiment  \
# 0        Somewhat-Bullish  [{'ticker': 'LIN', 'relevance_score': '0.02782...
# 1        Somewhat-Bullish  [{'ticker': 'LIN', 'relevance_score': '0.95919...
# 2        Somewhat-Bullish  [{'ticker': 'LIN', 'relevance_score': '0.74780...
# 3        Somewhat-Bullish  [{'ticker': 'BLK', 'relevance_score': '0.06550...
# 4        Somewhat-Bullish  [{'ticker': 'LIN', 'relevance_score': '0.95919...
#
#   ticker
# 0    LIN
# 1    LIN
# 2    LIN
# 3    LIN
# 4    LIN

# %%
import json

#Convert it to UpperCase for all the Columns for table insert
articles_data.columns = articles_data.columns.str.upper()

#Handle DataTypes for Table Insert
articles_data['TIME_PUBLISHED'] = pd.to_datetime(articles_data['TIME_PUBLISHED'], format='%Y%m%dT%H%M%S')
articles_data['AUTHORS'] = articles_data['AUTHORS'].apply(json.dumps)
articles_data['TOPICS'] = articles_data['TOPICS'].apply(json.dumps)
articles_data['TICKER_SENTIMENT'] = articles_data['TICKER_SENTIMENT'].apply(json.dumps)

# %%
from sqlalchemy import create_engine,text

#Create Engine to load data to data mart table
engine = create_engine('oracle://"dss_stock":stock@localhost:1521/?service_name=ORCL')

with engine.connect() as connection:
    connection.execute(text("TRUNCATE TABLE articles"))
    connection.commit()

#Load data to the Data mart Table
try:
    articles_data.to_sql('articles', con=engine, if_exists='append', index=False)
    print("Data insertion successful.")
except Exception as e:
    print(f"Error inserting data: {str(e)}")
# Out:
# Data insertion successful.
